# %%
import torch
print(torch.cuda.is_available())

# %%
# !ppip install unsloth transformers dataset trl accelerate peft bitsandbytes

# %%
# !pip install unsloth transformers dataset trl accelerate peft bitsandbytes

# %%
print("working")

# %%
from datasets import load_dataset

dataset = load_dataset(
    "json",
    data_files="bca_interview_dataset.json"
)
print(dataset)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name
)

print("Model loaded successfully")

# %%
def format_example(example):
  return{
      "text":f"instruction {example['instruction']}\nResponse: {example['response']}"
  }
dataset = dataset.map(format_example)
print(dataset["train"][0])

# %%
tokenizer.pad_token = tokenizer.eos_token

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=1,
    num_train_epochs=3,
    logging_steps=1,
    save_steps=10,
    push_to_hub=False, # Explicitly set to False to avoid 'push_to_hub_token' error
    remove_unused_columns=False # Keep all columns for dataset processing
)

print("Training configuration ready")

# %%
per_device_train_batch_size=1

# %%
num_train_epochs=3

# %%
logging_steps=1

# %%
save_steps=10

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
print(dataset)

# %%
print(dataset["train"][0])

# %%
print(type(model))

# %%
print(type(model))

# %%
print(tokenizer.pad_token)

# %%
print(torch.cuda.is_available())
print(dataset["train"][0])
print(tokenizer.pad_token)
print(type(model))

# %%
from trl import SFTTrainer

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    dataset_text_field="text",
    args=training_args
)

trainer.train()

# %%
from trl import SFTTrainer
from transformers import DataCollatorForLanguageModeling

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    args=training_args,
)

trainer.train()

# %%
from trl import SFTTrainer
from transformers import DataCollatorForLanguageModeling

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    args=training_args,
)

trainer.train()

# %%
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling

# Re-create TrainingArguments to include remove_unused_columns=False
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=1,
    num_train_epochs=3,
    logging_steps=1,
    save_steps=10,
    remove_unused_columns=False # Explicitly keep all columns
)

# Tokenize the dataset
def tokenize_function(examples):
    # This assumes 'tokenizer' is accessible from previous cells.
    # It will generate 'input_ids' and 'attention_mask'.
    return tokenizer(examples["text"], truncation=True, padding="max_length")

# Map the tokenization function to the dataset
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Initialize a data collator for causal language modeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    data_collator=data_collator # Pass the data collator
)

trainer.train()

# %%
def tokenize_function(example):
    return tokenizer(
        example["text"],
        padding="max_length",
        truncation=True,
        max_length=128
    )

tokenized_dataset = dataset.map(tokenize_function)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"]
)

trainer.train()

# %%
def tokenize_function(example):
    tokens = tokenizer(
        example["text"],
        padding="max_length",
        truncation=True,
        max_length=128
    )

    tokens["labels"] = tokens["input_ids"].copy()

    return tokens

tokenized_dataset = dataset.map(tokenize_function)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"]
)

trainer.train()

# %%
trainer.save_model("bca_interview_ai")
tokenizer.save_pretrained("bca_interview_ai")

# %%
prompt = "What is Python?"

inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

outputs = model.generate(
    **inputs,
    max_new_tokens=50
)

print(tokenizer.decode(outputs[0]))

# %%
while True:
    question = input("Ask AI: ")

    if question.lower() == "exit":
        break

    ask_ai(question)

# %%
while True:
    question = input("Ask AI: ")

    if question.lower() == "exit":
        break

    ask_ai(question)

# %%
while True:
    question = input("Ask AI: ")

    if question.lower() == "exit":
        break

    ask_ai(question)

# %%
def ask_ai(question):
    inputs = tokenizer(question, return_tensors="pt").to("cuda")

    outputs = model.generate(
        **inputs,
        max_new_tokens=100
    )

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    print(response)

# %%
ask_ai("What is Python?")

# %%
ask_ai("what is oops?")

# %%
trainer.save_model("bca_interview_ai")
tokenizer.save_pretrained("bca_interview_ai")

# %%
# 1. Add the updated notebook file to the staging area
# !git add notebook/training.ipynb

# 2. Commit the change with a descriptive message
# !git commit -m "Clear outputs to fix GitHub notebook rendering error"

# 3. Push the change to your active branch (main)
# !git push origin main

# %%
# 1. Fill in your details again
GITHUB_USERNAME = "tamas20006"
REPO_NAME = "ai_chatbot"
GITHUB_TOKEN = "your_github_personal_access_token_here"
BRANCH_NAME = "main"  # change this if you are using a different branch

# 2. Add and commit your cleared notebook
# !git add notebook/training.ipynb
# !git commit -m "Clear outputs to fix GitHub notebook rendering error"

# 3. Securely push using your token directly in the URL
# !git push https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git {BRANCH_NAME}

# %%
# 1. Fill in your details
GITHUB_USERNAME = "tamas20006"
GITHUB_EMAIL = "your_email@example.com"  # Your GitHub email
REPO_NAME = "ai_chatbot"
GITHUB_TOKEN = "your_github_personal_access_token_here"
BRANCH_NAME = "main"

# 2. Re-configure your Git settings
# !git config --global user.name "{GITHUB_USERNAME}"
# !git config --global user.email "{GITHUB_EMAIL}"

# 3. Re-initialize the repository to fix the "not a git repository" error
# !git init

# 4. Point it back to your existing GitHub repo
remote_url = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git remote add origin {remote_url}

# 5. Fetch the existing history from GitHub so they are synced
# !git fetch origin

# 6. Add your cleared notebook and commit it
# !git add notebook/training.ipynb
# !git commit -m "Clear outputs to fix GitHub notebook rendering error"

# 7. Push the changes securely back to your branch
# !git push origin {BRANCH_NAME}

# %%
# !pip install gradio

# %%
temperature=0.7
do_sample=True

# %%
outputs = model.generate(
    **inputs,
    max_new_tokens=100,
    temperature=0.7,
    do_sample=True
)

# %%
import gradio as gr
import torch

def chat(message, history):
    inputs = tokenizer(message, return_tensors="pt").to("cuda")

    outputs = model.generate(
        **inputs,
        max_new_tokens=150,
        temperature=0.7,
        do_sample=True
    )

    response = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )

    return response

demo = gr.ChatInterface(
    fn=chat,
    title="BCA Interview Assistant AI",
    description="TinyLlama fine-tuned AI chatbot",
    theme="soft"
)

demo.launch(share=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b996195b0b38541198.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b996195b0b38541198.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
